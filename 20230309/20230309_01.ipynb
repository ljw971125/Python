# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.rc('font', family='Malgun Gothic')

# %%
plt.rcParams["figure.figsize"] = (12,9)

# %%
data = np.arange(1, 100)
plt.plot(data)
plt.show()

# %%
data1 = np.arange(1,51)
plt.plot(data1)
data2 = np.arange(51,101)
plt.plot(data2)
plt.show()

# %%
data1 = np.arange(100,201)
plt.plot(data1)
data2 = np.arange(201,301)
plt.figure()
plt.plot(data2)
plt.show()

# %%
data1 = np.arange(100,201)
plt.subplot(2, 1, 1)
plt.plot(data1)

data2 = np.arange(201,301)
plt.subplot(2, 1, 2)
plt.plot(data2)

plt.show()

# %%
data1 = np.arange(100,201)
plt.subplot(211)
plt.plot(data1)

data2 = np.arange(201,301)
plt.subplot(212)
plt.plot(data2)

plt.show()

# %%
data1 = np.arange(100,201)
plt.subplot(1, 3, 1)
plt.plot(data1)

data2 = np.arange(201,301)
plt.subplot(1, 3, 2)
plt.plot(data2)

data3 = np.arange(301,401)
plt.subplot(1, 3, 3)
plt.plot(data3)

plt.show()

# %%
data = np.arange(1, 51)

fig, axes = plt.subplots(2, 3)

axes[0, 0].plot(data)
axes[0, 1].plot(data * data)
axes[0, 2].plot(data ** 3)
axes[1, 0].plot(data / 10)
axes[1, 1].plot(-data)
axes[1, 2].plot(data // 20)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7560\2507170365.py:12: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   plt.tight_layout()

# %%
plt.plot([1,2,3],[3,6,9])
plt.plot([1,2,3],[2,4,9])

plt.title('TITLE', fontsize=20)

plt.xlabel('X축', fontsize=20)
plt.ylabel('Y축', fontsize=20)

plt.xticks(rotation=90)
plt.yticks(rotation=90)

plt.show()

# %%
plt.plot(np.arange(10), np.arange(10)*2)
plt.plot(np.arange(10), np.arange(10)**2)
plt.plot(np.arange(10), np.log(np.arange(10)))

plt.title('TITLE', fontsize=20)

plt.xlabel('X축', fontsize=20)
plt.ylabel('Y축', fontsize=20)

plt.xticks(rotation=90)
plt.yticks(rotation=90)

plt.legend(['10*2','10**2','log'], fontsize=15)

plt.xlim(0,5)
plt.ylim(0.5, 10)

plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7560\1457261585.py:3: RuntimeWarning: divide by zero encountered in log
#   plt.plot(np.arange(10), np.log(np.arange(10)))

# %%
plt.plot(np.arange(10), np.arange(10)*2, marker='o', markersize=5)
plt.plot(np.arange(10), np.arange(10)*2-10, marker='v', markersize=10)
plt.plot(np.arange(10), np.arange(10)*2-20, marker='+', markersize=15)
plt.plot(np.arange(10), np.arange(10)*2-30, marker='*', markersize=20)

plt.title('TITLE', fontsize=20)

plt.xlabel('X축', fontsize=20)
plt.ylabel('Y축', fontsize=20)

plt.xticks(rotation=90)
plt.yticks(rotation=90)

plt.show()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.plot(np.arange(10), np.arange(10)*2, marker='o', linestyle='')
plt.plot(np.arange(10), np.arange(10)*2-10, marker='o',linestyle='-')
plt.plot(np.arange(10), np.arange(10)*2-20, marker='v',linestyle='--')
plt.plot(np.arange(10), np.arange(10)*2-30, marker='+', linestyle='-.')
plt.plot(np.arange(10), np.arange(10)*2-40, marker='*', linestyle=':')

plt.title('TITLE', fontsize=20)

plt.xlabel('X축', fontsize=20)
plt.ylabel('Y축', fontsize=20)

plt.xticks(rotation=90)
plt.yticks(rotation=90)

plt.show()

# %%
plt.plot(np.arange(10), np.arange(10)*2, marker='o', linestyle='-', color='b')
plt.plot(np.arange(10), np.arange(10)*2-10, marker='v',linestyle='--', color='c')
plt.plot(np.arange(10), np.arange(10)*2-20, marker='+',linestyle='-.', color='y')
plt.plot(np.arange(10), np.arange(10)*2-30, marker='*', linestyle=':', color='r')

plt.title('TITLE', fontsize=20)

plt.xlabel('X축', fontsize=20)
plt.ylabel('Y축', fontsize=20)

plt.xticks(rotation=90)
plt.yticks(rotation=90)

plt.show()

# %%
plt.plot(np.arange(10), np.arange(10)*2, color='b', alpha=0.1)
plt.plot(np.arange(10), np.arange(10)*2-10, color='c', alpha=0.3)
plt.plot(np.arange(10), np.arange(10)*2-20, color='y', alpha=0.6)
plt.plot(np.arange(10), np.arange(10)*2-30, color='r', alpha=1.0)

plt.title('TITLE', fontsize=20)

plt.xlabel('X축', fontsize=20)
plt.ylabel('Y축', fontsize=20)

plt.xticks(rotation=90)
plt.yticks(rotation=90)

plt.grid()

plt.show()
